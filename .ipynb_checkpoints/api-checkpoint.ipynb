# %%
import requests

# %%
URL = "https://meowfacts.herokuapp.com/?count=3"
res = requests.get(URL)

# %%
json_data =res.json()

# %%
print(json_data)
# Out:
# {'data': ['Tabby cats are thought to get their name from Attab, a district in Baghdad, now the capital of Iraq.', 'A form of AIDS exists in cats.', 'In the Middle Ages, during the Festival of Saint John, cats were burned alive in town squares.']}

# %%
import pandas as pd
df = pd.DataFrame(json_data["data"], columns=["Fact"])
df
# Out:
#                                                 Fact
# 0  Tabby cats are thought to get their name from ...
# 1                     A form of AIDS exists in cats.
# 2  In the Middle Ages, during the Festival of Sai...
