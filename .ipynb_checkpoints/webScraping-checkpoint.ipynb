# %%
import requests as req

url = "https://www.scrapethissite.com/pages/simple/"

res = req.get(url)

# %%
with open("Scrapmaterial/countries.html", "w",encoding="utf-8") as f:
    f.write(res.text)
